# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load cleaned dataset for time series analysis
df = pd.read_csv("../data/cleaned/ev_cleaned_for_time_series.csv")

df.head()
# Out:
#       region  year  EV_sales  sales_share  EV_stock  stock_share
# 0  Australia  2011      49.0       0.0065      49.0      0.00039
# 1  Australia  2012     125.0       0.0300     150.0      0.00240
# 2  Australia  2013     145.0       0.0340     295.0      0.00460
# 3  Australia  2014     660.0       0.1600     940.0      0.01400
# 4  Australia  2015     880.0       0.2000    1800.0      0.02700

# %%
# Aggregate global EV sales by year
ts_global = (
    df.groupby("year", as_index=False)["EV_sales"]
    .sum()
    .sort_values("year")
)

ts_global.head()
# Out:
#    year       EV_sales
# 0  2010    8164.166667
# 1  2011   48834.166667
# 2  2012  111091.166667
# 3  2013  197230.166667
# 4  2014  290034.733333

# %%
# Time series plot
plt.figure(figsize=(10,6))
plt.plot(ts_global["year"], ts_global["EV_sales"], marker="o")
plt.title("Global EV Sales Over Time")
plt.xlabel("Year")
plt.ylabel("EV Sales")
plt.grid(True)
plt.show()

# %%
from statsmodels.tsa.ar_model import AutoReg

ts = ts_global.set_index("year")["EV_sales"]

model = AutoReg(ts, lags=1, old_names=False)
model_fit = model.fit()

print(model_fit.summary())
# Out:
#                             AutoReg Model Results
# ...
# Dep. Variable:               EV_sales   No. Observations:                   14
# Model:                     AutoReg(1)   Log Likelihood                -189.047
# Method:               Conditional MLE   S.D. of innovations         500397.817
# Date:                Tue, 10 Mar 2026   AIC                            384.095
# Time:                        22:20:36   BIC                            385.789
# Sample:                             1   HQIC                           383.746
#                                    14
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        1.645e+05   1.73e+05      0.951      0.342   -1.75e+05    5.04e+05
# EV_sales.L1     1.3781      0.056     24.418      0.000       1.267       1.489
#                                     Roots
# ...

# %%
forecast = model_fit.predict(start=len(ts), end=len(ts)+2)

print("Forecast for next 3 years:")
print(forecast)
# Out:
# Forecast for next 3 years:
# 14    1.552825e+07
# 15    2.156428e+07
# 16    2.988262e+07
# dtype: float64
# C:\Users\User\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\User\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %%
fitted_values = model_fit.fittedvalues
plt.figure(figsize=(10,6))
plt.plot(ts.index, ts.values, marker="o", label="Actual EV Sales")
plt.plot(fitted_values.index, fitted_values.values, marker="o", label="Fitted AR(1)")
plt.title("AR(1) Model Fit for Global EV Sales")
plt.xlabel("Year")
plt.ylabel("EV Sales")
plt.legend()
plt.grid(True)
plt.show()
